# %% [markdown]
# Brandon Poblette
# Project part 3
# Hypothesis: Players with higher true shooting percentages will be have higher net ratings

# %%
#Importing all the needed packages for data visualization and exploration
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


player_stats = pd.read_csv('Seasons_Stats.csv')

# %% [markdown]
# Create 4 graphs visualizing the relation between 4 different features (x) and net_rating (y)

# %%
sns.scatterplot(data=player_stats, x='PTS', y='WS')
# Out:
# <Axes: xlabel='PTS', ylabel='WS'>

# %%
sns.scatterplot(data=player_stats, x='eFG%', y='WS')
# Out:
# <Axes: xlabel='eFG%', ylabel='WS'>

# %%
sns.scatterplot(data=player_stats, x='FT%', y='WS')
# Out:
# <Axes: xlabel='FT%', ylabel='WS'>

# %%
sns.scatterplot(data=player_stats, x='TS%', y='WS')
# Out:
# <Axes: xlabel='TS%', ylabel='WS'>
